# %%
import cv2
import os
import numpy as np

def apply_low_light(image_path, output_dir, brightness_factor=0.7, gamma_value=0.5, blur_kernel_size=5, color_shift_factor=0.5, add_lens_flare=False, noise_mean=(0, 0, 0), noise_std=(10, 10, 10)):
    # Load the image
    image = cv2.imread(image_path)

    # Convert image from BGR to RGB color space
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Adjust brightness using multiplication factor
    darkened_image = np.zeros_like(image_rgb)
    for channel in range(3):
        darkened_image[:,:,channel] = cv2.multiply(image_rgb[:,:,channel], brightness_factor)

    # Apply gamma correction
    gamma_corrected = darkened_image ** gamma_value

    # Apply blur
    blurred_image = cv2.GaussianBlur(gamma_corrected, (blur_kernel_size, blur_kernel_size), 0)

    # Apply color shift
    color_shifted_image = np.zeros_like(blurred_image)
    for channel in range(3):
        color_shifted_image[:,:,channel] = cv2.multiply(blurred_image[:,:,channel], color_shift_factor)

    # Increase the color shift for the blue channel to introduce a blue tint
    color_shifted_image[:,:,2] *= 1.6  # Blue channel

    # Add Gaussian noise
    noise = np.random.normal(noise_mean, noise_std, color_shifted_image.shape)
    noisy_image = np.clip(color_shifted_image + noise, 0, 255).astype(np.uint8)

    # Add lens flare or light artifacts if enabled
    #if add_lens_flare:
        # Implement lens flare or light artifact logic here
        # You can overlay or blend images of light sources onto the low light image

    # Convert the image back to BGR color space
    transformed_image = cv2.cvtColor(noisy_image, cv2.COLOR_RGB2BGR)

    # Save the transformed image
    image_name = os.path.basename(image_path)
    output_path = os.path.join(output_dir, image_name)
    cv2.imwrite(output_path, transformed_image)


# Example usage
dataset_dir = '../Datasets/Kaggle Face Mask Detection Full/images'
output_dir = '../Datasets/Kaggle Face Mask Detection Full/dark/images'  # Directory where transformed images will be saved


# Parameters for adjusting the transforms
brightness_factor = 0.9  # Adjust the brightness of the image (0.0 - 1.0)
gamma_value = 0.7  # Adjust the gamma correction value (0.1 - 2.0)
blur_kernel_size = 5  # Adjust the kernel size for blurring (odd values)
color_shift_factor = 0.8  # Adjust the color shift factor (0.0 - 1.0)
add_lens_flare = True  # Enable/disable adding lens flare or light artifacts
noise_mean = (0, 0, 0)  # Adjust the mean of the noise (R, G, B)
noise_std = (2, 2, 2)  # Adjust the standard deviation of the noise (R, G, B)

# Iterate over the images in the dataset directory
for filename in os.listdir(dataset_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_path = os.path.join(dataset_dir, filename)
        apply_low_light(image_path, output_dir, brightness_factor, gamma_value, blur_kernel_size, color_shift_factor, add_lens_flare)
        print(f"Transformed image saved: {filename}")
# Out:
# Transformed image saved: maksssksksss0.png
# Transformed image saved: maksssksksss1.png
# Transformed image saved: maksssksksss10.png
# Transformed image saved: maksssksksss100.png
# Transformed image saved: maksssksksss101.png
# Transformed image saved: maksssksksss102.png
# Transformed image saved: maksssksksss103.png
# Transformed image saved: maksssksksss104.png
# Transformed image saved: maksssksksss105.png
# Transformed image saved: maksssksksss106.png
# Transformed image saved: maksssksksss107.png
# Transformed image saved: maksssksksss108.png
# Transformed image saved: maksssksksss109.png
# Transformed image saved: maksssksksss11.png
# Transformed image saved: maksssksksss110.png
# Transformed image saved: maksssksksss111.png
# Transformed image saved: maksssksksss112.png
# Transformed image saved: maksssksksss113.png
# Transformed image saved: maksssksksss114.png
# Transformed image saved: maksssksksss115.png
# Transformed image saved: maksssksksss116.png
# Transformed image saved: maksssksksss117.png
# Transformed image saved: maksssksksss118.png
# Transformed image saved: maksssksksss119.png
# Transformed image saved: maksssksksss12.png
# Transformed image saved: maksssksksss120.png
# Transformed image saved: maksssksksss121.png
# Transformed image saved: maksssksksss122.png
# Transformed image saved: maksssksksss123.png
# Transformed image saved: maksssksksss124.png
# Transformed image saved: maksssksksss125.png
# Transformed image saved: maksssksksss126.png
# Transformed image saved: maksssksksss127.png
# Transformed image saved: maksssksksss128.png
# Transformed image saved: maksssksksss129.png
# Transformed image saved: maksssksksss13.png
# Transformed image saved: maksssksksss130.png
# Transformed image saved: maksssksksss131.png
# Transformed image saved: maksssksksss132.png
# Transformed image saved: maksssksksss133.png
# Transformed image saved: maksssksksss134.png
# Transformed image saved: maksssksksss135.png
# Transformed image saved: maksssksksss136.png
# Transformed image saved: maksssksksss137.png
# Transformed image saved: maksssksksss138.png
# Transformed image saved: maksssksksss139.png
# Transformed image saved: maksssksksss14.png
# Transformed image saved: maksssksksss140.png
# Transformed image saved: maksssksksss141.png
# Transformed image saved: maksssksksss142.png
# Transformed image saved: maksssksksss143.png
# Transformed image saved: maksssksksss144.png
# Transformed image saved: maksssksksss145.png
# Transformed image saved: maksssksksss146.png
# Transformed image saved: maksssksksss147.png
# Transformed image saved: maksssksksss148.png
# Transformed image saved: maksssksksss149.png
# Transformed image saved: maksssksksss15.png
# Transformed image saved: maksssksksss150.png
# Transformed image saved: maksssksksss151.png
# Transformed image saved: maksssksksss152.png
# Transformed image saved: maksssksksss153.png
# Transformed image saved: maksssksksss154.png
# Transformed image saved: maksssksksss155.png
# Transformed image saved: maksssksksss156.png
# Transformed image saved: maksssksksss157.png
# Transformed image saved: maksssksksss158.png
# Transformed image saved: maksssksksss159.png
# Transformed image saved: maksssksksss16.png
# Transformed image saved: maksssksksss160.png
# Transformed image saved: maksssksksss161.png
# Transformed image saved: maksssksksss162.png
# Transformed image saved: maksssksksss163.png
# Transformed image saved: maksssksksss164.png
# Transformed image saved: maksssksksss165.png
# Transformed image saved: maksssksksss166.png
# Transformed image saved: maksssksksss167.png
# Transformed image saved: maksssksksss168.png
# Transformed image saved: maksssksksss169.png
# Transformed image saved: maksssksksss17.png
# Transformed image saved: maksssksksss170.png
# Transformed image saved: maksssksksss171.png
# Transformed image saved: maksssksksss172.png
# Transformed image saved: maksssksksss173.png
# Transformed image saved: maksssksksss174.png
# Transformed image saved: maksssksksss175.png
# Transformed image saved: maksssksksss176.png
# Transformed image saved: maksssksksss177.png
# Transformed image saved: maksssksksss178.png
# Transformed image saved: maksssksksss179.png
# Transformed image saved: maksssksksss18.png
# Transformed image saved: maksssksksss180.png
# Transformed image saved: maksssksksss181.png
# Transformed image saved: maksssksksss182.png
# Transformed image saved: maksssksksss183.png
# Transformed image saved: maksssksksss184.png
# Transformed image saved: maksssksksss185.png
# Transformed image saved: maksssksksss186.png
# Transformed image saved: maksssksksss187.png
# Transformed image saved: maksssksksss188.png
# Transformed image saved: maksssksksss189.png
# Transformed image saved: maksssksksss19.png
# Transformed image saved: maksssksksss190.png
# Transformed image saved: maksssksksss191.png
# Transformed image saved: maksssksksss192.png
# Transformed image saved: maksssksksss193.png
# Transformed image saved: maksssksksss194.png
# Transformed image saved: maksssksksss195.png
# Transformed image saved: maksssksksss196.png
# Transformed image saved: maksssksksss197.png
# Transformed image saved: maksssksksss198.png
# Transformed image saved: maksssksksss199.png
# Transformed image saved: maksssksksss2.png
# Transformed image saved: maksssksksss20.png
# Transformed image saved: maksssksksss200.png
# Transformed image saved: maksssksksss201.png
# Transformed image saved: maksssksksss202.png
# Transformed image saved: maksssksksss203.png
# Transformed image saved: maksssksksss204.png
# Transformed image saved: maksssksksss205.png
# Transformed image saved: maksssksksss206.png
# Transformed image saved: maksssksksss207.png
# Transformed image saved: maksssksksss208.png
# Transformed image saved: maksssksksss209.png
# Transformed image saved: maksssksksss21.png
# Transformed image saved: maksssksksss210.png
# Transformed image saved: maksssksksss211.png
# Transformed image saved: maksssksksss212.png
# Transformed image saved: maksssksksss213.png
# Transformed image saved: maksssksksss214.png
# Transformed image saved: maksssksksss215.png
# Transformed image saved: maksssksksss216.png
# Transformed image saved: maksssksksss217.png
# Transformed image saved: maksssksksss218.png
# Transformed image saved: maksssksksss219.png
# Transformed image saved: maksssksksss22.png
# Transformed image saved: maksssksksss220.png
# Transformed image saved: maksssksksss221.png
# Transformed image saved: maksssksksss222.png
# Transformed image saved: maksssksksss223.png
# Transformed image saved: maksssksksss224.png
# Transformed image saved: maksssksksss225.png
# Transformed image saved: maksssksksss226.png
# Transformed image saved: maksssksksss227.png
# Transformed image saved: maksssksksss228.png
# Transformed image saved: maksssksksss229.png
# Transformed image saved: maksssksksss23.png
# Transformed image saved: maksssksksss230.png
# Transformed image saved: maksssksksss231.png
# Transformed image saved: maksssksksss232.png
# Transformed image saved: maksssksksss233.png
# Transformed image saved: maksssksksss234.png
# Transformed image saved: maksssksksss235.png
# Transformed image saved: maksssksksss236.png
# Transformed image saved: maksssksksss237.png
# Transformed image saved: maksssksksss238.png
# Transformed image saved: maksssksksss239.png
# Transformed image saved: maksssksksss24.png
# Transformed image saved: maksssksksss240.png
# Transformed image saved: maksssksksss241.png
# Transformed image saved: maksssksksss242.png
# Transformed image saved: maksssksksss243.png
# Transformed image saved: maksssksksss244.png
# Transformed image saved: maksssksksss245.png
# Transformed image saved: maksssksksss246.png
# Transformed image saved: maksssksksss247.png
# Transformed image saved: maksssksksss248.png
# Transformed image saved: maksssksksss249.png
# Transformed image saved: maksssksksss25.png
# Transformed image saved: maksssksksss250.png
# Transformed image saved: maksssksksss251.png
# Transformed image saved: maksssksksss252.png
# Transformed image saved: maksssksksss253.png
# Transformed image saved: maksssksksss254.png
# Transformed image saved: maksssksksss255.png
# Transformed image saved: maksssksksss256.png
# Transformed image saved: maksssksksss257.png
# Transformed image saved: maksssksksss258.png
# Transformed image saved: maksssksksss259.png
# Transformed image saved: maksssksksss26.png
# Transformed image saved: maksssksksss260.png
# Transformed image saved: maksssksksss261.png
# Transformed image saved: maksssksksss262.png
# Transformed image saved: maksssksksss263.png
# Transformed image saved: maksssksksss264.png
# Transformed image saved: maksssksksss265.png
# Transformed image saved: maksssksksss266.png
# Transformed image saved: maksssksksss267.png
# Transformed image saved: maksssksksss268.png
# Transformed image saved: maksssksksss269.png
# Transformed image saved: maksssksksss27.png
# Transformed image saved: maksssksksss270.png
# Transformed image saved: maksssksksss271.png
# Transformed image saved: maksssksksss272.png
# Transformed image saved: maksssksksss273.png
# Transformed image saved: maksssksksss274.png
# Transformed image saved: maksssksksss275.png
# Transformed image saved: maksssksksss276.png
# Transformed image saved: maksssksksss277.png
# Transformed image saved: maksssksksss278.png
# Transformed image saved: maksssksksss279.png
# Transformed image saved: maksssksksss28.png
# Transformed image saved: maksssksksss280.png
# Transformed image saved: maksssksksss281.png
# Transformed image saved: maksssksksss282.png
# Transformed image saved: maksssksksss283.png
# Transformed image saved: maksssksksss284.png
# Transformed image saved: maksssksksss285.png
# Transformed image saved: maksssksksss286.png
# Transformed image saved: maksssksksss287.png
# Transformed image saved: maksssksksss288.png
# Transformed image saved: maksssksksss289.png
# Transformed image saved: maksssksksss29.png
# Transformed image saved: maksssksksss290.png
# Transformed image saved: maksssksksss291.png
# Transformed image saved: maksssksksss292.png
# Transformed image saved: maksssksksss293.png
# Transformed image saved: maksssksksss294.png
# Transformed image saved: maksssksksss295.png
# Transformed image saved: maksssksksss296.png
# Transformed image saved: maksssksksss297.png
# Transformed image saved: maksssksksss298.png
# Transformed image saved: maksssksksss299.png
# Transformed image saved: maksssksksss3.png
# Transformed image saved: maksssksksss30.png
# Transformed image saved: maksssksksss300.png
# Transformed image saved: maksssksksss301.png
# Transformed image saved: maksssksksss302.png
# Transformed image saved: maksssksksss303.png
# Transformed image saved: maksssksksss304.png
# Transformed image saved: maksssksksss305.png
# Transformed image saved: maksssksksss306.png
# Transformed image saved: maksssksksss307.png
# Transformed image saved: maksssksksss308.png
# Transformed image saved: maksssksksss309.png
# Transformed image saved: maksssksksss31.png
# Transformed image saved: maksssksksss310.png
# Transformed image saved: maksssksksss311.png
# Transformed image saved: maksssksksss312.png
# Transformed image saved: maksssksksss313.png
# Transformed image saved: maksssksksss314.png
# Transformed image saved: maksssksksss315.png
# Transformed image saved: maksssksksss316.png
# Transformed image saved: maksssksksss317.png
# Transformed image saved: maksssksksss318.png
# Transformed image saved: maksssksksss319.png
# Transformed image saved: maksssksksss32.png
# Transformed image saved: maksssksksss320.png
# Transformed image saved: maksssksksss321.png
# Transformed image saved: maksssksksss322.png
# Transformed image saved: maksssksksss323.png
# Transformed image saved: maksssksksss324.png
# Transformed image saved: maksssksksss325.png
# Transformed image saved: maksssksksss326.png
# Transformed image saved: maksssksksss327.png
# Transformed image saved: maksssksksss328.png
# Transformed image saved: maksssksksss329.png
# Transformed image saved: maksssksksss33.png
# Transformed image saved: maksssksksss330.png
# Transformed image saved: maksssksksss331.png
# Transformed image saved: maksssksksss332.png
# Transformed image saved: maksssksksss333.png
# Transformed image saved: maksssksksss334.png
# Transformed image saved: maksssksksss335.png
# Transformed image saved: maksssksksss336.png
# Transformed image saved: maksssksksss337.png
# Transformed image saved: maksssksksss338.png
# Transformed image saved: maksssksksss339.png
# Transformed image saved: maksssksksss34.png
# Transformed image saved: maksssksksss340.png
# Transformed image saved: maksssksksss341.png
# Transformed image saved: maksssksksss342.png
# Transformed image saved: maksssksksss343.png
# Transformed image saved: maksssksksss344.png
# Transformed image saved: maksssksksss345.png
# Transformed image saved: maksssksksss346.png
# Transformed image saved: maksssksksss347.png
# Transformed image saved: maksssksksss348.png
# Transformed image saved: maksssksksss349.png
# Transformed image saved: maksssksksss35.png
# Transformed image saved: maksssksksss350.png
# Transformed image saved: maksssksksss351.png
# Transformed image saved: maksssksksss352.png
# Transformed image saved: maksssksksss353.png
# Transformed image saved: maksssksksss354.png
# Transformed image saved: maksssksksss355.png
# Transformed image saved: maksssksksss356.png
# Transformed image saved: maksssksksss357.png
# Transformed image saved: maksssksksss358.png
# Transformed image saved: maksssksksss359.png
# Transformed image saved: maksssksksss36.png
# Transformed image saved: maksssksksss360.png
# Transformed image saved: maksssksksss361.png
# Transformed image saved: maksssksksss362.png
# Transformed image saved: maksssksksss363.png
# Transformed image saved: maksssksksss364.png
# Transformed image saved: maksssksksss365.png
# Transformed image saved: maksssksksss366.png
# Transformed image saved: maksssksksss367.png
# Transformed image saved: maksssksksss368.png
# Transformed image saved: maksssksksss369.png
# Transformed image saved: maksssksksss37.png
# Transformed image saved: maksssksksss370.png
# Transformed image saved: maksssksksss371.png
# Transformed image saved: maksssksksss372.png
# Transformed image saved: maksssksksss373.png
# Transformed image saved: maksssksksss374.png
# Transformed image saved: maksssksksss375.png
# Transformed image saved: maksssksksss376.png
# Transformed image saved: maksssksksss377.png
# Transformed image saved: maksssksksss378.png
# Transformed image saved: maksssksksss379.png
# Transformed image saved: maksssksksss38.png
# Transformed image saved: maksssksksss380.png
# Transformed image saved: maksssksksss381.png
# Transformed image saved: maksssksksss382.png
# Transformed image saved: maksssksksss383.png
# Transformed image saved: maksssksksss384.png
# Transformed image saved: maksssksksss385.png
# Transformed image saved: maksssksksss386.png
# Transformed image saved: maksssksksss387.png
# Transformed image saved: maksssksksss388.png
# Transformed image saved: maksssksksss389.png
# Transformed image saved: maksssksksss39.png
# Transformed image saved: maksssksksss390.png
# Transformed image saved: maksssksksss391.png
# Transformed image saved: maksssksksss392.png
# Transformed image saved: maksssksksss393.png
# Transformed image saved: maksssksksss394.png
# Transformed image saved: maksssksksss395.png
# Transformed image saved: maksssksksss396.png
# Transformed image saved: maksssksksss397.png
# Transformed image saved: maksssksksss398.png
# Transformed image saved: maksssksksss399.png
# Transformed image saved: maksssksksss4.png
# Transformed image saved: maksssksksss40.png
# Transformed image saved: maksssksksss400.png
# Transformed image saved: maksssksksss401.png
# Transformed image saved: maksssksksss402.png
# Transformed image saved: maksssksksss403.png
# Transformed image saved: maksssksksss404.png
# Transformed image saved: maksssksksss405.png
# Transformed image saved: maksssksksss406.png
# Transformed image saved: maksssksksss407.png
# Transformed image saved: maksssksksss408.png
# Transformed image saved: maksssksksss409.png
# Transformed image saved: maksssksksss41.png
# Transformed image saved: maksssksksss410.png
# Transformed image saved: maksssksksss411.png
# Transformed image saved: maksssksksss412.png
# Transformed image saved: maksssksksss413.png
# Transformed image saved: maksssksksss414.png
# Transformed image saved: maksssksksss415.png
# Transformed image saved: maksssksksss416.png
# Transformed image saved: maksssksksss417.png
# Transformed image saved: maksssksksss418.png
# Transformed image saved: maksssksksss419.png
# Transformed image saved: maksssksksss42.png
# Transformed image saved: maksssksksss420.png
# Transformed image saved: maksssksksss421.png
# Transformed image saved: maksssksksss422.png
# Transformed image saved: maksssksksss423.png
# Transformed image saved: maksssksksss424.png
# Transformed image saved: maksssksksss425.png
# Transformed image saved: maksssksksss426.png
# Transformed image saved: maksssksksss427.png
# Transformed image saved: maksssksksss428.png
# Transformed image saved: maksssksksss429.png
# Transformed image saved: maksssksksss43.png
# Transformed image saved: maksssksksss430.png
# Transformed image saved: maksssksksss431.png
# Transformed image saved: maksssksksss432.png
# Transformed image saved: maksssksksss433.png
# Transformed image saved: maksssksksss434.png
# Transformed image saved: maksssksksss435.png
# Transformed image saved: maksssksksss436.png
# Transformed image saved: maksssksksss437.png
# Transformed image saved: maksssksksss438.png
# Transformed image saved: maksssksksss439.png
# Transformed image saved: maksssksksss44.png
# Transformed image saved: maksssksksss440.png
# Transformed image saved: maksssksksss441.png
# Transformed image saved: maksssksksss442.png
# Transformed image saved: maksssksksss443.png
# Transformed image saved: maksssksksss444.png
# Transformed image saved: maksssksksss445.png
# Transformed image saved: maksssksksss446.png
# Transformed image saved: maksssksksss447.png
# Transformed image saved: maksssksksss448.png
# Transformed image saved: maksssksksss449.png
# Transformed image saved: maksssksksss45.png
# Transformed image saved: maksssksksss450.png
# Transformed image saved: maksssksksss451.png
# Transformed image saved: maksssksksss452.png
# Transformed image saved: maksssksksss453.png
# Transformed image saved: maksssksksss454.png
# Transformed image saved: maksssksksss455.png
# Transformed image saved: maksssksksss456.png
# Transformed image saved: maksssksksss457.png
# Transformed image saved: maksssksksss458.png
# Transformed image saved: maksssksksss459.png
# Transformed image saved: maksssksksss46.png
# Transformed image saved: maksssksksss460.png
# Transformed image saved: maksssksksss461.png
# Transformed image saved: maksssksksss462.png
# Transformed image saved: maksssksksss463.png
# Transformed image saved: maksssksksss464.png
# Transformed image saved: maksssksksss465.png
# Transformed image saved: maksssksksss466.png
# Transformed image saved: maksssksksss467.png
# Transformed image saved: maksssksksss468.png
# Transformed image saved: maksssksksss469.png
# Transformed image saved: maksssksksss47.png
# Transformed image saved: maksssksksss470.png
# Transformed image saved: maksssksksss471.png
# Transformed image saved: maksssksksss472.png
# Transformed image saved: maksssksksss473.png
# Transformed image saved: maksssksksss474.png
# Transformed image saved: maksssksksss475.png
# Transformed image saved: maksssksksss476.png
# Transformed image saved: maksssksksss477.png
# Transformed image saved: maksssksksss478.png
# Transformed image saved: maksssksksss479.png
# Transformed image saved: maksssksksss48.png
# Transformed image saved: maksssksksss480.png
# Transformed image saved: maksssksksss481.png
# Transformed image saved: maksssksksss482.png
# Transformed image saved: maksssksksss483.png
# Transformed image saved: maksssksksss484.png
# Transformed image saved: maksssksksss485.png
# Transformed image saved: maksssksksss486.png
# Transformed image saved: maksssksksss487.png
# Transformed image saved: maksssksksss488.png
# Transformed image saved: maksssksksss489.png
# Transformed image saved: maksssksksss49.png
# Transformed image saved: maksssksksss490.png
# Transformed image saved: maksssksksss491.png
# Transformed image saved: maksssksksss492.png
# Transformed image saved: maksssksksss493.png
# Transformed image saved: maksssksksss494.png
# Transformed image saved: maksssksksss495.png
# Transformed image saved: maksssksksss496.png
# Transformed image saved: maksssksksss497.png
# Transformed image saved: maksssksksss498.png
# Transformed image saved: maksssksksss499.png
# Transformed image saved: maksssksksss5.png
# Transformed image saved: maksssksksss50.png
# Transformed image saved: maksssksksss500.png
# Transformed image saved: maksssksksss501.png
# Transformed image saved: maksssksksss502.png
# Transformed image saved: maksssksksss503.png
# Transformed image saved: maksssksksss504.png
# Transformed image saved: maksssksksss505.png
# Transformed image saved: maksssksksss506.png
# Transformed image saved: maksssksksss507.png
# Transformed image saved: maksssksksss508.png
# Transformed image saved: maksssksksss509.png
# Transformed image saved: maksssksksss51.png
# Transformed image saved: maksssksksss510.png
# Transformed image saved: maksssksksss511.png
# Transformed image saved: maksssksksss512.png
# Transformed image saved: maksssksksss513.png
# Transformed image saved: maksssksksss514.png
# Transformed image saved: maksssksksss515.png
# Transformed image saved: maksssksksss516.png
# Transformed image saved: maksssksksss517.png
# Transformed image saved: maksssksksss518.png
# Transformed image saved: maksssksksss519.png
# Transformed image saved: maksssksksss52.png
# Transformed image saved: maksssksksss520.png
# Transformed image saved: maksssksksss521.png
# Transformed image saved: maksssksksss522.png
# Transformed image saved: maksssksksss523.png
# Transformed image saved: maksssksksss524.png
# Transformed image saved: maksssksksss525.png
# Transformed image saved: maksssksksss526.png
# Transformed image saved: maksssksksss527.png
# Transformed image saved: maksssksksss528.png
# Transformed image saved: maksssksksss529.png
# Transformed image saved: maksssksksss53.png
# Transformed image saved: maksssksksss530.png
# Transformed image saved: maksssksksss531.png
# Transformed image saved: maksssksksss532.png
# Transformed image saved: maksssksksss533.png
# Transformed image saved: maksssksksss534.png
# Transformed image saved: maksssksksss535.png
# Transformed image saved: maksssksksss536.png
# Transformed image saved: maksssksksss537.png
# Transformed image saved: maksssksksss538.png
# Transformed image saved: maksssksksss539.png
# Transformed image saved: maksssksksss54.png
# Transformed image saved: maksssksksss540.png
# Transformed image saved: maksssksksss541.png
# Transformed image saved: maksssksksss542.png
# Transformed image saved: maksssksksss543.png
# Transformed image saved: maksssksksss544.png
# Transformed image saved: maksssksksss545.png
# Transformed image saved: maksssksksss546.png
# Transformed image saved: maksssksksss547.png
# Transformed image saved: maksssksksss548.png
# Transformed image saved: maksssksksss549.png
# Transformed image saved: maksssksksss55.png
# Transformed image saved: maksssksksss550.png
# Transformed image saved: maksssksksss551.png
# Transformed image saved: maksssksksss552.png
# Transformed image saved: maksssksksss553.png
# Transformed image saved: maksssksksss554.png
# Transformed image saved: maksssksksss555.png
# Transformed image saved: maksssksksss556.png
# Transformed image saved: maksssksksss557.png
# Transformed image saved: maksssksksss558.png
# Transformed image saved: maksssksksss559.png
# Transformed image saved: maksssksksss56.png
# Transformed image saved: maksssksksss560.png
# Transformed image saved: maksssksksss561.png
# Transformed image saved: maksssksksss562.png
# Transformed image saved: maksssksksss563.png
# Transformed image saved: maksssksksss564.png
# Transformed image saved: maksssksksss565.png
# Transformed image saved: maksssksksss566.png
# Transformed image saved: maksssksksss567.png
# Transformed image saved: maksssksksss568.png
# Transformed image saved: maksssksksss569.png
# Transformed image saved: maksssksksss57.png
# Transformed image saved: maksssksksss570.png
# Transformed image saved: maksssksksss571.png
# Transformed image saved: maksssksksss572.png
# Transformed image saved: maksssksksss573.png
# Transformed image saved: maksssksksss574.png
# Transformed image saved: maksssksksss575.png
# Transformed image saved: maksssksksss576.png
# Transformed image saved: maksssksksss577.png
# Transformed image saved: maksssksksss578.png
# Transformed image saved: maksssksksss579.png
# Transformed image saved: maksssksksss58.png
# Transformed image saved: maksssksksss580.png
# Transformed image saved: maksssksksss581.png
# Transformed image saved: maksssksksss582.png
# Transformed image saved: maksssksksss583.png
# Transformed image saved: maksssksksss584.png
# Transformed image saved: maksssksksss585.png
# Transformed image saved: maksssksksss586.png
# Transformed image saved: maksssksksss587.png
# Transformed image saved: maksssksksss588.png
# Transformed image saved: maksssksksss589.png
# Transformed image saved: maksssksksss59.png
# Transformed image saved: maksssksksss590.png
# Transformed image saved: maksssksksss591.png
# Transformed image saved: maksssksksss592.png
# Transformed image saved: maksssksksss593.png
# Transformed image saved: maksssksksss594.png
# Transformed image saved: maksssksksss595.png
# Transformed image saved: maksssksksss596.png
# Transformed image saved: maksssksksss597.png
# Transformed image saved: maksssksksss598.png
# Transformed image saved: maksssksksss599.png
# Transformed image saved: maksssksksss6.png
# Transformed image saved: maksssksksss60.png
# Transformed image saved: maksssksksss600.png
# Transformed image saved: maksssksksss601.png
# Transformed image saved: maksssksksss602.png
# Transformed image saved: maksssksksss603.png
# Transformed image saved: maksssksksss604.png
# Transformed image saved: maksssksksss605.png
# Transformed image saved: maksssksksss606.png
# Transformed image saved: maksssksksss607.png
# Transformed image saved: maksssksksss608.png
# Transformed image saved: maksssksksss609.png
# Transformed image saved: maksssksksss61.png
# Transformed image saved: maksssksksss610.png
# Transformed image saved: maksssksksss611.png
# Transformed image saved: maksssksksss612.png
# Transformed image saved: maksssksksss613.png
# Transformed image saved: maksssksksss614.png
# Transformed image saved: maksssksksss615.png
# Transformed image saved: maksssksksss616.png
# Transformed image saved: maksssksksss617.png
# Transformed image saved: maksssksksss618.png
# Transformed image saved: maksssksksss619.png
# Transformed image saved: maksssksksss62.png
# Transformed image saved: maksssksksss620.png
# Transformed image saved: maksssksksss621.png
# Transformed image saved: maksssksksss622.png
# Transformed image saved: maksssksksss623.png
# Transformed image saved: maksssksksss624.png
# Transformed image saved: maksssksksss625.png
# Transformed image saved: maksssksksss626.png
# Transformed image saved: maksssksksss627.png
# Transformed image saved: maksssksksss628.png
# Transformed image saved: maksssksksss629.png
# Transformed image saved: maksssksksss63.png
# Transformed image saved: maksssksksss630.png
# Transformed image saved: maksssksksss631.png
# Transformed image saved: maksssksksss632.png
# Transformed image saved: maksssksksss633.png
# Transformed image saved: maksssksksss634.png
# Transformed image saved: maksssksksss635.png
# Transformed image saved: maksssksksss636.png
# Transformed image saved: maksssksksss637.png
# Transformed image saved: maksssksksss638.png
# Transformed image saved: maksssksksss639.png
# Transformed image saved: maksssksksss64.png
# Transformed image saved: maksssksksss640.png
# Transformed image saved: maksssksksss641.png
# Transformed image saved: maksssksksss642.png
# Transformed image saved: maksssksksss643.png
# Transformed image saved: maksssksksss644.png
# Transformed image saved: maksssksksss645.png
# Transformed image saved: maksssksksss646.png
# Transformed image saved: maksssksksss647.png
# Transformed image saved: maksssksksss648.png
# Transformed image saved: maksssksksss649.png
# Transformed image saved: maksssksksss65.png
# Transformed image saved: maksssksksss650.png
# Transformed image saved: maksssksksss651.png
# Transformed image saved: maksssksksss652.png
# Transformed image saved: maksssksksss653.png
# Transformed image saved: maksssksksss654.png
# Transformed image saved: maksssksksss655.png
# Transformed image saved: maksssksksss656.png
# Transformed image saved: maksssksksss657.png
# Transformed image saved: maksssksksss658.png
# Transformed image saved: maksssksksss659.png
# Transformed image saved: maksssksksss66.png
# Transformed image saved: maksssksksss660.png
# Transformed image saved: maksssksksss661.png
# Transformed image saved: maksssksksss662.png
# Transformed image saved: maksssksksss663.png
# Transformed image saved: maksssksksss664.png
# Transformed image saved: maksssksksss665.png
# Transformed image saved: maksssksksss666.png
# Transformed image saved: maksssksksss667.png
# Transformed image saved: maksssksksss668.png
# Transformed image saved: maksssksksss669.png
# Transformed image saved: maksssksksss67.png
# Transformed image saved: maksssksksss670.png
# Transformed image saved: maksssksksss671.png
# Transformed image saved: maksssksksss672.png
# Transformed image saved: maksssksksss673.png
# Transformed image saved: maksssksksss674.png
# Transformed image saved: maksssksksss675.png
# Transformed image saved: maksssksksss676.png
# Transformed image saved: maksssksksss677.png
# Transformed image saved: maksssksksss678.png
# Transformed image saved: maksssksksss679.png
# Transformed image saved: maksssksksss68.png
# Transformed image saved: maksssksksss680.png
# Transformed image saved: maksssksksss681.png
# Transformed image saved: maksssksksss682.png
# Transformed image saved: maksssksksss683.png
# Transformed image saved: maksssksksss684.png
# Transformed image saved: maksssksksss685.png
# Transformed image saved: maksssksksss686.png
# Transformed image saved: maksssksksss687.png
# Transformed image saved: maksssksksss688.png
# Transformed image saved: maksssksksss689.png
# Transformed image saved: maksssksksss69.png
# Transformed image saved: maksssksksss690.png
# Transformed image saved: maksssksksss691.png
# Transformed image saved: maksssksksss692.png
# Transformed image saved: maksssksksss693.png
# Transformed image saved: maksssksksss694.png
# Transformed image saved: maksssksksss695.png
# Transformed image saved: maksssksksss696.png
# Transformed image saved: maksssksksss697.png
# Transformed image saved: maksssksksss698.png
# Transformed image saved: maksssksksss699.png
# Transformed image saved: maksssksksss7.png
# Transformed image saved: maksssksksss70.png
# Transformed image saved: maksssksksss700.png
# Transformed image saved: maksssksksss701.png
# Transformed image saved: maksssksksss702.png
# Transformed image saved: maksssksksss703.png
# Transformed image saved: maksssksksss704.png
# Transformed image saved: maksssksksss705.png
# Transformed image saved: maksssksksss706.png
# Transformed image saved: maksssksksss707.png
# Transformed image saved: maksssksksss708.png
# Transformed image saved: maksssksksss709.png
# Transformed image saved: maksssksksss71.png
# Transformed image saved: maksssksksss710.png
# Transformed image saved: maksssksksss711.png
# Transformed image saved: maksssksksss712.png
# Transformed image saved: maksssksksss713.png
# Transformed image saved: maksssksksss714.png
# Transformed image saved: maksssksksss715.png
# Transformed image saved: maksssksksss716.png
# Transformed image saved: maksssksksss717.png
# Transformed image saved: maksssksksss718.png
# Transformed image saved: maksssksksss719.png
# Transformed image saved: maksssksksss72.png
# Transformed image saved: maksssksksss720.png
# Transformed image saved: maksssksksss721.png
# Transformed image saved: maksssksksss722.png
# Transformed image saved: maksssksksss723.png
# Transformed image saved: maksssksksss724.png
# Transformed image saved: maksssksksss725.png
# Transformed image saved: maksssksksss726.png
# Transformed image saved: maksssksksss727.png
# Transformed image saved: maksssksksss728.png
# Transformed image saved: maksssksksss729.png
# Transformed image saved: maksssksksss73.png
# Transformed image saved: maksssksksss730.png
# Transformed image saved: maksssksksss731.png
# Transformed image saved: maksssksksss732.png
# Transformed image saved: maksssksksss733.png
# Transformed image saved: maksssksksss734.png
# Transformed image saved: maksssksksss735.png
# Transformed image saved: maksssksksss736.png
# Transformed image saved: maksssksksss737.png
# Transformed image saved: maksssksksss738.png
# Transformed image saved: maksssksksss739.png
# Transformed image saved: maksssksksss74.png
# Transformed image saved: maksssksksss740.png
# Transformed image saved: maksssksksss741.png
# Transformed image saved: maksssksksss742.png
# Transformed image saved: maksssksksss743.png
# Transformed image saved: maksssksksss744.png
# Transformed image saved: maksssksksss745.png
# Transformed image saved: maksssksksss746.png
# Transformed image saved: maksssksksss747.png
# Transformed image saved: maksssksksss748.png
# Transformed image saved: maksssksksss749.png
# Transformed image saved: maksssksksss75.png
# Transformed image saved: maksssksksss750.png
# Transformed image saved: maksssksksss751.png
# Transformed image saved: maksssksksss752.png
# Transformed image saved: maksssksksss753.png
# Transformed image saved: maksssksksss754.png
# Transformed image saved: maksssksksss755.png
# Transformed image saved: maksssksksss756.png
# Transformed image saved: maksssksksss757.png
# Transformed image saved: maksssksksss758.png
# Transformed image saved: maksssksksss759.png
# Transformed image saved: maksssksksss76.png
# Transformed image saved: maksssksksss760.png
# Transformed image saved: maksssksksss761.png
# Transformed image saved: maksssksksss762.png
# Transformed image saved: maksssksksss763.png
# Transformed image saved: maksssksksss764.png
# Transformed image saved: maksssksksss765.png
# Transformed image saved: maksssksksss766.png
# Transformed image saved: maksssksksss767.png
# Transformed image saved: maksssksksss768.png
# Transformed image saved: maksssksksss769.png
# Transformed image saved: maksssksksss77.png
# Transformed image saved: maksssksksss770.png
# Transformed image saved: maksssksksss771.png
# Transformed image saved: maksssksksss772.png
# Transformed image saved: maksssksksss773.png
# Transformed image saved: maksssksksss774.png
# Transformed image saved: maksssksksss775.png
# Transformed image saved: maksssksksss776.png
# Transformed image saved: maksssksksss777.png
# Transformed image saved: maksssksksss778.png
# Transformed image saved: maksssksksss779.png
# Transformed image saved: maksssksksss78.png
# Transformed image saved: maksssksksss780.png
# Transformed image saved: maksssksksss781.png
# Transformed image saved: maksssksksss782.png
# Transformed image saved: maksssksksss783.png
# Transformed image saved: maksssksksss784.png
# Transformed image saved: maksssksksss785.png
# Transformed image saved: maksssksksss786.png
# Transformed image saved: maksssksksss787.png
# Transformed image saved: maksssksksss788.png
# Transformed image saved: maksssksksss789.png
# Transformed image saved: maksssksksss79.png
# Transformed image saved: maksssksksss790.png
# Transformed image saved: maksssksksss791.png
# Transformed image saved: maksssksksss792.png
# Transformed image saved: maksssksksss793.png
# Transformed image saved: maksssksksss794.png
# Transformed image saved: maksssksksss795.png
# Transformed image saved: maksssksksss796.png
# Transformed image saved: maksssksksss797.png
# Transformed image saved: maksssksksss798.png
# Transformed image saved: maksssksksss799.png
# Transformed image saved: maksssksksss8.png
# Transformed image saved: maksssksksss80.png
# Transformed image saved: maksssksksss800.png
# Transformed image saved: maksssksksss801.png
# Transformed image saved: maksssksksss802.png
# Transformed image saved: maksssksksss803.png
# Transformed image saved: maksssksksss804.png
# Transformed image saved: maksssksksss805.png
# Transformed image saved: maksssksksss806.png
# Transformed image saved: maksssksksss807.png
# Transformed image saved: maksssksksss808.png
# Transformed image saved: maksssksksss809.png
# Transformed image saved: maksssksksss81.png
# Transformed image saved: maksssksksss810.png
# Transformed image saved: maksssksksss811.png
# Transformed image saved: maksssksksss812.png
# Transformed image saved: maksssksksss813.png
# Transformed image saved: maksssksksss814.png
# Transformed image saved: maksssksksss815.png
# Transformed image saved: maksssksksss816.png
# Transformed image saved: maksssksksss817.png
# Transformed image saved: maksssksksss818.png
# Transformed image saved: maksssksksss819.png
# Transformed image saved: maksssksksss82.png
# Transformed image saved: maksssksksss820.png
# Transformed image saved: maksssksksss821.png
# Transformed image saved: maksssksksss822.png
# Transformed image saved: maksssksksss823.png
# Transformed image saved: maksssksksss824.png
# Transformed image saved: maksssksksss825.png
# Transformed image saved: maksssksksss826.png
# Transformed image saved: maksssksksss827.png
# Transformed image saved: maksssksksss828.png
# Transformed image saved: maksssksksss829.png
# Transformed image saved: maksssksksss83.png
# Transformed image saved: maksssksksss830.png
# Transformed image saved: maksssksksss831.png
# Transformed image saved: maksssksksss832.png
# Transformed image saved: maksssksksss833.png
# Transformed image saved: maksssksksss834.png
# Transformed image saved: maksssksksss835.png
# Transformed image saved: maksssksksss836.png
# Transformed image saved: maksssksksss837.png
# Transformed image saved: maksssksksss838.png
# Transformed image saved: maksssksksss839.png
# Transformed image saved: maksssksksss84.png
# Transformed image saved: maksssksksss840.png
# Transformed image saved: maksssksksss841.png
# Transformed image saved: maksssksksss842.png
# Transformed image saved: maksssksksss843.png
# Transformed image saved: maksssksksss844.png
# Transformed image saved: maksssksksss845.png
# Transformed image saved: maksssksksss846.png
# Transformed image saved: maksssksksss847.png
# Transformed image saved: maksssksksss848.png
# Transformed image saved: maksssksksss849.png
# Transformed image saved: maksssksksss85.png
# Transformed image saved: maksssksksss850.png
# Transformed image saved: maksssksksss851.png
# Transformed image saved: maksssksksss852.png
# Transformed image saved: maksssksksss86.png
# Transformed image saved: maksssksksss87.png
# Transformed image saved: maksssksksss88.png
# Transformed image saved: maksssksksss89.png
# Transformed image saved: maksssksksss9.png
# Transformed image saved: maksssksksss90.png
# Transformed image saved: maksssksksss91.png
# Transformed image saved: maksssksksss92.png
# Transformed image saved: maksssksksss93.png
# Transformed image saved: maksssksksss94.png
# Transformed image saved: maksssksksss95.png
# Transformed image saved: maksssksksss96.png
# Transformed image saved: maksssksksss97.png
# Transformed image saved: maksssksksss98.png
# Transformed image saved: maksssksksss99.png
